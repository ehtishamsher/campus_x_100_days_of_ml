# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from kagglehub) (4.68.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from requests->kagglehub) (2026.6.17)
# Requirement already satisfied: colorama in c:\users\irvinei\miniconda3\envs\polynominal_regression\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.13

# %%
# The following code will only execute
# successfully when compression is complete

import kagglehub

# Download latest version
path = kagglehub.competition_download('digit-recognizer')

print("Path to competition files:", path)
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[2], line 7
#       4 import kagglehub
#       6 # Download latest version
# ----> 7 path = kagglehub.competition_download('digit-recognizer')
#       9 print("Path to competition files:", path)
#
# File c:\Users\IRVINEi\miniconda3\envs\polynominal_regression\lib\site-packages\kagglehub\competition.py:23, in competition_download(handle, path, force_download)
#      21 h = parse_competition_handle(handle)
#      22 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 23 path, _ = registry.competition_resolver(h, path, force_download=force_download)
#      24 return path
#
# File c:\Users\IRVINEi\miniconda3\envs\polynominal_regression\lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\IRVINEi\miniconda3\envs\polynominal_regression\lib\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)
#      27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File c:\Users\IRVINEi\miniconda3\envs\polynominal_regression\lib\site-packages\kagglehub\http_resolver.py:50, in CompetitionHttpResolver._resolve(self, h, path, force_download)
#      48     if cached_path:
#      49         return cached_path, None
# ---> 50     raise UnauthenticatedError()
#      52 out_path = get_cached_path(h, path)
#      53 if path:
#      54     # For single file downloads.
#
# UnauthenticatedError: User is not authenticated

# %%
import pandas as pd
import requests
import os

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMDI4ZmYxYTM3MTRmNmFjNjM1YmU0ZTNlNTU0ZjY2NiIsIm5iZiI6MTcxNDI0MzYwMS4yNjgsInN1YiI6IjY2MmQ0ODExYzU2ZDJkMDEyOWNjNmJhOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.PbTq4B-yXaYD-qVmY_fMAhXPx3bHW5yzMpFDcW5QBrU"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg","genre_ids":[35,10749],"id":1632181,"title":"Accidental Partners","original_language":"es","original_title":"Socias por accidente","overview":"Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.","popularity":26.8564,"poster_path":"/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg","release_date":"2026-03-12","softcore":false,"video":false,"vote_average":9.069,"vote_count":305},{"adult":false,"backdrop_path":"/zMwhWailP1WY7sb6AoE6b8ugoy.jpg","genre_ids":[12,16,10751,14],"id":1007757,"title":"Swapped","original_language":"en","original_title":"Swapped","overview":"A small woodland creature and a majestic bird, two natural sworn enemies of the Valley, magically trade places and set off on an adventure of a lifetime to switch back. Their journey soon uncovers a greater threat—one that could endanger not only their species, but the entire valley
# ...

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','vote_average','vote_count']]
# Out:
#          id                                          title  \
# 0   1632181                            Accidental Partners
# 1   1007757                                        Swapped
# 2       278                       The Shawshank Redemption
# 3    936075                                        Michael
# 4       238                                  The Godfather
# 5    687163                              Project Hail Mary
# 6       240                          The Godfather Part II
# 7       424                               Schindler's List
# 8       389                                   12 Angry Men
# 9   1330021                    Remarkably Bright Creatures
# 10  1383731                                      Protector
# 11      129                                  Spirited Away
# 12      155                                The Dark Knight
# 13    19404                    Dilwale Dulhania Le Jayenge
# 14      497                                 The Green Mile
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
    for i in range(1,429):
        url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)

        headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMDI4ZmYxYTM3MTRmNmFjNjM1YmU0ZTNlNTU0ZjY2NiIsIm5iZiI6MTcxNDI0MzYwMS4yNjgsInN1YiI6IjY2MmQ0ODExYzU2ZDJkMDEyOWNjNmJhOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.PbTq4B-yXaYD-qVmY_fMAhXPx3bHW5yzMpFDcW5QBrU"
        }
        temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','vote_average','vote_count']]
        df =pd.concat([df,temp_df],ignore_index = True)

# %%
df
# Out:
#            id                                          title  \
# 0     1632181                            Accidental Partners
# 1     1007757                                        Swapped
# 2         278                       The Shawshank Redemption
# 3      936075                                        Michael
# 4         238                                  The Godfather
# ...       ...                                            ...
# 8555  1181678                          ¿Quieres ser mi hijo?
# 8556      122  The Lord of the Rings: The Return of the King
# 8557   496243                                       Parasite
# 8558   372058                                     Your Name.
# 8559   157336                                   Interstellar
#
#                                                overview release_date  \
# 0     Two women discover they were both scammed by t...   2026-03-12
# 1     A small woodland creature and a majestic bird,...   2026-05-01
# ...

# %%
df.shape
# Out:
# (8560, 6)

# %%
df.to_csv('movies.csv')
